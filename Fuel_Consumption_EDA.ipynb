# %% [markdown]
# # Fuel Consumption Data Analysis
#
# In this project, we will perform Exploratory Data Analysis (EDA)
# on the FuelConsumption dataset using:
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
#
# We will understand the dataset, clean the data, analyze
# relationships between variables, and visualize important patterns.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset
#
# We will load the FuelConsumption.csv file using Pandas.

# %%
df = pd.read_csv("FuelConsumption.csv")
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %% [markdown]
# Dataset Shape
#
# The `shape` property tells us the number of rows and columns.

# %%
df.shape
# Out:
# (1067, 13)

# %% [markdown]
# First 10 records of the dataset

# %%
df.head(10)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
# 5       2014  ACURA         RLX     MID-SIZE         3.5          6
# 6       2014  ACURA          TL     MID-SIZE         3.5          6
# 7       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 8       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 9       2014  ACURA         TSX      COMPACT         2.4          4
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# ...

# %% [markdown]
# Last 10 record of the dataset

# %%
df.tail(10)
# Out:
#       MODELYEAR   MAKE     MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 1057       2014  VOLVO   S60 AWD         COMPACT         2.5          5
# 1058       2014  VOLVO   S60 AWD         COMPACT         3.0          6
# 1059       2014  VOLVO       S80        MID-SIZE         3.2          6
# 1060       2014  VOLVO   S80 AWD        MID-SIZE         3.0          6
# 1061       2014  VOLVO      XC60     SUV - SMALL         3.2          6
# 1062       2014  VOLVO  XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO  XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO  XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO  XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO  XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 1057          AS6        X                  11.6                  8.3
# ...

# %% [markdown]
# ## Column Names
#
# Let's check all the column names available in the dataset.

# %%
df.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %% [markdown]
# ## Dataset Information
#
# `info()` gives us information about:
#
# - Number of rows
# - Column names
# - Data types
# - Non-null values
# - Memory usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %% [markdown]
# ## Statistical Summary
#
# The `describe()` function provides statistical information
# about numerical columns.

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %% [markdown]
# **Check The Data Types**

# %%
df.dtypes
# Out:
# MODELYEAR                     int64
# MAKE                         object
# MODEL                        object
# VEHICLECLASS                 object
# ENGINESIZE                  float64
# CYLINDERS                     int64
# TRANSMISSION                 object
# FUELTYPE                     object
# FUELCONSUMPTION_CITY        float64
# FUELCONSUMPTION_HWY         float64
# FUELCONSUMPTION_COMB        float64
# FUELCONSUMPTION_COMB_MPG      int64
# CO2EMISSIONS                  int64
# dtype: object

# %% [markdown]
# ## Missing Value Analysis
#
# We will check whether any columns contain missing values.

# %%
df.isnull().sum()
# Out:
# MODELYEAR                   0
# MAKE                        0
# MODEL                       0
# VEHICLECLASS                0
# ENGINESIZE                  0
# CYLINDERS                   0
# TRANSMISSION                0
# FUELTYPE                    0
# FUELCONSUMPTION_CITY        0
# FUELCONSUMPTION_HWY         0
# FUELCONSUMPTION_COMB        0
# FUELCONSUMPTION_COMB_MPG    0
# CO2EMISSIONS                0
# dtype: int64

# %% [markdown]
# **Check the `Duplicated` Rows**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Unique Values
#
# Let's understand the categorical columns in the dataset.

# %%
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
print("Number of Makes:",df["MAKE"].nunique())
print("Number of Models:",df["MODEL"].nunique())
print("Number of Vehicleclasses:",df["VEHICLECLASS"].nunique())
print("Number of Fueltypes:",df["FUELTYPE"].nunique())
print("Number of Transmissions:",df["TRANSMISSION"].nunique())
# Out:
# Number of Makes: 39
# Number of Models: 663
# Number of Vehicleclasses: 16
# Number of Fueltypes: 4
# Number of Transmissions: 22

# %% [markdown]
# ## Explore Categorical Columns

# %%
print("Fuel Types:")
print(df["FUELTYPE"].unique())

print("\nTransmission Types:")
print(df["TRANSMISSION"].unique())

print("\nVehicle Classes:")
print(df["VEHICLECLASS"].unique())
# Out:
# Fuel Types:
# ['Z' 'D' 'X' 'E']
#
# Transmission Types:
# ['AS5' 'M6' 'AV7' 'AS6' 'A6' 'AM7' 'AV8' 'AS8' 'A7' 'A8' 'M7' 'A4' 'M5'
#  'AV' 'A5' 'AM6' 'AS7' 'A9' 'AS9' 'AV6' 'AS4' 'AM5']
#
# Vehicle Classes:
# ['COMPACT' 'SUV - SMALL' 'MID-SIZE' 'MINICOMPACT' 'SUBCOMPACT'
#  'TWO-SEATER' 'FULL-SIZE' 'STATION WAGON - SMALL' 'SUV - STANDARD'
#  'VAN - CARGO' 'VAN - PASSENGER' 'PICKUP TRUCK - STANDARD' 'MINIVAN'
#  'SPECIAL PURPOSE VEHICLE' 'STATION WAGON - MID-SIZE'
#  'PICKUP TRUCK - SMALL']

# %% [markdown]
# ## Fuel Type Distribution
#
# We will count how many vehicles use each type of fuel.

# %%
df["FUELTYPE"].value_counts()
# Out:
# FUELTYPE
# X    514
# Z    434
# E     92
# D     27
# Name: count, dtype: int64

# %% [markdown]
# ## Fuel Type Visualization

# %%
plt.figure(figsize=(8,4))
sns.countplot(data = df , x = "FUELTYPE",color='yellow')
plt.title("Fuel Type Distribution")
plt.xlabel("Fuel Type")
plt.ylabel("Number of Vehicles")
plt.show()

# %% [markdown]
# ## Insight
#
# - This visualization shows which fuel types are most common in the dataset.

# %% [markdown]
# ## Vehicle Class Distribution

# %%
plt.figure(figsize = (12,6))
sns.countplot(data = df,
              y = "VEHICLECLASS",
              order = df["VEHICLECLASS"].value_counts().index,color = "orange")
plt.title("Vehicle Class Distribution")
plt.xlabel("Number Of Vehicle")
plt.ylabel("Vehicle CLass")
plt.show()

# %% [markdown]
# ## Vehicle Manufacturer Analysis
#
# Let's find the manufacturers with the highest number of vehicles.

# %%
make_counts = df["MAKE"].value_counts()
make_counts.head(10)
# Out:
# MAKE
# FORD             90
# CHEVROLET        86
# BMW              64
# MERCEDES-BENZ    59
# GMC              49
# AUDI             49
# TOYOTA           49
# PORSCHE          44
# VOLKSWAGEN       42
# DODGE            39
# Name: count, dtype: int64

# %% [markdown]
# ## Top 10 Manufacturers

# %%
plt.figure(figsize = (8,5))
sns.barplot(x = make_counts.head(10).values,
            y = make_counts.head(10).index,color = "Orange")
plt.title("Top 10 Vehicle Manufacturers")
plt.xlabel("Number Of Vehicles")
plt.ylabel("Manufacturers")
plt.show()

# %% [markdown]
# ## Engine Size Analysis
#
# We will examine the distribution of engine sizes.

# %%
plt.figure(figsize = (8,5))
sns.histplot(data = df,
             x = "ENGINESIZE",
             bins = 20,
             kde = True,
            color = "red")
plt.title("Distribution Of Engine Size")
plt.xlabel("Engine Size")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Cylinder Distribution

# %%
plt.figure(figsize = (8,4))
sns.countplot(data = df,
              x = "CYLINDERS",
              color = "orange")
plt.title("Distribution of Cylinders")
plt.xlabel("Number of Cylinders")
plt.ylabel("Number of Vehicles")

plt.show()

# %% [markdown]
# ## CO₂ Emissions Analysis
#
# CO2EMISSIONS is an important target variable.
#
# We will analyze its distribution.

# %%
plt.figure(figsize = (8,4))
sns.histplot(data = df,
             x = "CO2EMISSIONS",
             bins = 30,
             kde = True,
            color = "Orange")
plt.title("Distribution of CO₂ Emissions")
plt.xlabel("CO₂ Emissions")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8, 4))

sns.boxplot(x=df["CO2EMISSIONS"])

plt.title("Boxplot of CO₂ Emissions")
plt.xlabel("CO₂ Emissions")

plt.show()

# %% [markdown]
# This helps identify possible outliers

# %% [markdown]
# ## Fuel Consumption Analysis

# %%
plt.figure(figsize = (12,6))
sns.histplot(data = df,
             x = "FUELCONSUMPTION_COMB",
             bins = 30,
             kde = True,
             color = "Blue")
plt.title("Combined Fuel Consumption Distribution")
plt.xlabel("Combined Fuel Consumption")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## City vs Highway Fuel Consumption

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(
    data=df,
    x="FUELCONSUMPTION_CITY",
    y="FUELCONSUMPTION_HWY",
    color = "Green")

plt.title("City vs Highway Fuel Consumption")
plt.xlabel("City Fuel Consumption")
plt.ylabel("Highway Fuel Consumption")

plt.show()

# %% [markdown]
# **Insight**
#
# Generally, vehicles with higher city fuel consumption also tend to have higher highway fuel consumption.

# %% [markdown]
# ## Engine Size vs CO₂ Emissions
#
# Let's investigate whether larger engines are associated
# with higher CO₂ emissions.

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(
    data=df,
    x="ENGINESIZE",
    y="CO2EMISSIONS",
    color = "red")

plt.title("Engine Size vs CO₂ Emissions")
plt.xlabel("Engine Size")
plt.ylabel("CO₂ Emissions")

plt.show()

# %% [markdown]
# **Insight**
#
# There is a visible positive relationship: vehicles with larger engines generally tend to produce more CO₂ emissions.

# %% [markdown]
# ## Cylinders vs CO₂ Emissions

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(
    data=df,
    x="CYLINDERS",
    y="CO2EMISSIONS",
    color = "Yellow")
plt.title("Cylinders vs CO₂ Emissions")
plt.xlabel("Number of Cylinders")
plt.ylabel("CO₂ Emissions")

plt.show()

# %% [markdown]
# ## Fuel Consumption vs CO₂ Emissions

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(
    data=df,
    x="FUELCONSUMPTION_COMB",
    y="CO2EMISSIONS",
    color = "green")

plt.title("Fuel Consumption vs CO₂ Emissions")
plt.xlabel("Combined Fuel Consumption")
plt.ylabel("CO₂ Emissions")

plt.show()

# %% [markdown]
# **Insight**
#
# Higher combined fuel consumption is generally associated with higher CO₂ emissions.

# %% [markdown]
# ## MPG vs CO₂ Emissions

# %%
plt.figure(figsize = (8,4))
sns.scatterplot( data = df,
                 x="FUELCONSUMPTION_COMB_MPG",
                 y="CO2EMISSIONS",
                 color = "green")
plt.title("Combined MPG vs CO₂ Emissions")
plt.xlabel("Combined MPG")
plt.ylabel("CO₂ Emissions")

plt.show()

# %% [markdown]
# **Insight**
#
# - There is generally a negative relationship:
# - Higher MPG → Lower CO₂ emissions

# %% [markdown]
# ## Correlation Analysis
#
# Correlation helps us understand the relationship between
# numerical variables.
#
# Correlation ranges from -1 to +1:
#
# - +1 → Strong positive relationship
# - 0 → No linear relationship
# - -1 → Strong negative relationship

# %%
numeric_df = df.select_dtypes(include=np.number)
correlation = numeric_df.corr()
correlation
# Out:
#                           MODELYEAR  ENGINESIZE  CYLINDERS  \
# MODELYEAR                       NaN         NaN        NaN
# ENGINESIZE                      NaN    1.000000   0.934011
# CYLINDERS                       NaN    0.934011   1.000000
# FUELCONSUMPTION_CITY            NaN    0.832225   0.796473
# FUELCONSUMPTION_HWY             NaN    0.778746   0.724594
# FUELCONSUMPTION_COMB            NaN    0.819482   0.776788
# FUELCONSUMPTION_COMB_MPG        NaN   -0.808554  -0.770430
# CO2EMISSIONS                    NaN    0.874154   0.849685
#
#                           FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# MODELYEAR                                  NaN                  NaN
# ENGINESIZE                            0.832225             0.778746
# CYLINDERS                             0.796473             0.724594
# FUELCONSUMPTION_CITY                  1.000000             0.965718
# FUELCONSUMPTION_HWY                   0.965718             1.000000
# ...

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(12, 8))

sns.heatmap(
    correlation,
    annot=True,
    cmap="coolwarm",
    fmt=".2f")

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ## Highest CO₂ Emitting Vehicles
#
# Let's identify the vehicles with the highest CO₂ emissions.

# %%
df.nlargest(10, "CO2EMISSIONS")[
    ["MAKE", "MODEL", "ENGINESIZE", "CYLINDERS", "CO2EMISSIONS"]
]
# Out:
#             MAKE                   MODEL  ENGINESIZE  CYLINDERS  CO2EMISSIONS
# 349         FORD              E350 WAGON         6.8         10           488
# 75       BENTLEY                MULSANNE         6.8          8           437
# 227    CHEVROLET  EXPRESS 3500 PASSENGER         6.0          8           435
# 451          GMC   SAVANA 3500 PASSENGER         6.0          8           435
# 224    CHEVROLET  EXPRESS 2500 PASSENGER         6.0          8           432
# 448          GMC   SAVANA 2500 PASSENGER         6.0          8           432
# 350         FORD          E350 WAGON FFV         5.4          8           421
# 633  LAMBORGHINI         AVENTADOR COUPE         6.5         12           421
# 226    CHEVROLET  EXPRESS 3500 PASSENGER         4.8          8           419
# 450          GMC   SAVANA 3500 PASSENGER         4.8          8           419

# %% [markdown]
# ## Top 10 Most Fuel-Efficient Vehicles

# %%
df.nlargest(10, "FUELCONSUMPTION_COMB_MPG")[
    ["MAKE", "MODEL", "ENGINESIZE", "FUELCONSUMPTION_COMB_MPG", "CO2EMISSIONS"]]
# Out:
#             MAKE               MODEL  ENGINESIZE  FUELCONSUMPTION_COMB_MPG  \
# 988       TOYOTA             PRIUS c         1.5                        60
# 487        HONDA       ACCORD HYBRID         2.0                        59
# 987       TOYOTA               PRIUS         1.8                        59
# 1042  VOLKSWAGEN  JETTA TURBO HYBRID         1.4                        52
# 415         FORD       FUSION HYBRID         2.0                        51
# 989       TOYOTA             PRIUS v         1.8                        51
# 655        LEXUS             CT 200h         1.8                        50
# 970       TOYOTA     CAMRY HYBRID LE         2.5                        50
# 2          ACURA          ILX HYBRID         1.5                        48
# 342         FORD        C-MAX HYBRID         2.0                        47
#
#       CO2EMISSIONS
# 988            108
# 487            110
# 987            110
# 1042           124
# 415            126
# 989            126
# ...

# %% [markdown]
# Here we use MPG, where higher MPG generally indicates better fuel efficiency.

# %% [markdown]
# ## Average CO₂ by Fuel Type

# %%
df.groupby("FUELTYPE")["CO2EMISSIONS"].mean().sort_values(ascending=False)
# Out:
# FUELTYPE
# E    291.086957
# Z    268.529954
# X    241.097276
# D    227.777778
# Name: CO2EMISSIONS, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="FUELTYPE",
    y="CO2EMISSIONS",
    color = "orange",
    estimator="mean")

plt.title("Average CO₂ Emissions by Fuel Type")
plt.xlabel("Fuel Type")
plt.ylabel("Average CO₂ Emissions")

plt.show()

# %% [markdown]
# ## Average CO₂ by Cylinder

# %%
df.groupby("CYLINDERS")["CO2EMISSIONS"].mean()
# Out:
# CYLINDERS
# 3     144.750000
# 4     201.107143
# 5     223.888889
# 6     260.603933
# 8     331.869048
# 10    394.777778
# 12    375.176471
# Name: CO2EMISSIONS, dtype: float64

# %%
plt.figure(figsize=(8, 5))

sns.barplot(
    data=df,
    x="CYLINDERS",
    y="CO2EMISSIONS",
    color = "orange",
    estimator="mean")

plt.title("Average CO₂ Emissions by Number of Cylinders")
plt.xlabel("Cylinders")
plt.ylabel("Average CO₂ Emissions")

plt.show()

# %% [markdown]
# ## Analysis

# %%
co2 = df["CO2EMISSIONS"].to_numpy()

print("Mean CO₂:", np.mean(co2))
print("Median CO₂:", np.median(co2))
print("Minimum CO₂:", np.min(co2))
print("Maximum CO₂:", np.max(co2))
print("Standard Deviation:", np.std(co2))
# Out:
# Mean CO₂: 256.2286785379569
# Median CO₂: 251.0
# Minimum CO₂: 108
# Maximum CO₂: 488
# Standard Deviation: 63.34260099404252

# %%
print("25th Percentile:", np.percentile(co2, 25))
print("50th Percentile:", np.percentile(co2, 50))
print("75th Percentile:", np.percentile(co2, 75))
# Out:
# 25th Percentile: 207.0
# 50th Percentile: 251.0
# 75th Percentile: 294.0

# %% [markdown]
# ## Outlier Detection
#
# We will use the Interquartile Range (IQR) method.
#
# IQR = Q3 - Q1
#
# Lower Bound = Q1 - 1.5 × IQR
#
# Upper Bound = Q3 + 1.5 × IQR

# %%
Q1 = df["CO2EMISSIONS"].quantile(0.25)
Q3 = df["CO2EMISSIONS"].quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Q1: 207.0
# Q3: 294.0
# IQR: 87.0
# Lower Bound: 76.5
# Upper Bound: 424.5

# %%
outliers = df[
    (df["CO2EMISSIONS"] < lower_bound) |
    (df["CO2EMISSIONS"] > upper_bound)
]

print("Number of outliers:", len(outliers))
# Out:
# Number of outliers: 6

# %% [markdown]
# ## Pairplot
#
# A pairplot allows us to visualize relationships between
# multiple numerical variables.

# %%
selected_columns = [
    "ENGINESIZE",
    "CYLINDERS",
    "FUELCONSUMPTION_COMB",
    "FUELCONSUMPTION_COMB_MPG",
    "CO2EMISSIONS"]

sns.pairplot(
    df[selected_columns + ["FUELTYPE"]],
    hue="FUELTYPE",
    palette="viridis")
plt.show()

# %% [markdown]
# # Final EDA Insights
#
# ## Dataset
# - The dataset contains 1,067 vehicles.
# - There are 13 columns.
# - The dataset contains numerical and categorical variables.
# - There are no missing values.
#
# ## Vehicle Characteristics
# - Engine size and number of cylinders vary across vehicles.
# - Different manufacturers and vehicle classes are represented.
# - Multiple fuel types and transmission types are available.
#
# ## Fuel Consumption
# - City and highway fuel consumption are positively related.
# - Combined fuel consumption is related to CO₂ emissions.
# - Higher MPG generally corresponds to lower CO₂ emissions.
#
# ## CO₂ Emissions
# - Engine size has a positive relationship with CO₂ emissions.
# - Vehicles with more cylinders generally tend to have higher CO₂ emissions.
# - Fuel consumption and CO₂ emissions show a strong relationship.
#
# ## Business/Analytical Insights
# - Larger engines generally consume more fuel.
# - Higher fuel consumption generally results in higher CO₂ emissions.
# - Fuel-efficient vehicles tend to have higher MPG and lower CO₂ emissions.
# - Engine size, cylinders, and fuel consumption can be useful variables
#   for predicting CO₂ emissions.
